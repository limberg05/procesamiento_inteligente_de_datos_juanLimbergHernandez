# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df_diabetes = datasets.load_diabetes()
x= df_diabetes.data[:,2].reshape(-1,1)
y=df_diabetes.target.reshape(-1,1)
df_diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]], shape=(442, 10)),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size = 0.3, random_state=50)

# %%
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
X_train, Y_train
# Out:
# (array([[-0.03422907],
#         [-0.05578531],
#         [ 0.01858372],
#         [ 0.04121778],
#         [-0.01806189],
#         [-0.00728377],
#         [ 0.03043966],
#         [ 0.00888341],
#         [ 0.13714305],
#         [ 0.01858372],
#         [-0.00081689],
#         [ 0.01535029],
#         [-0.03207344],
#         [ 0.03906215],
#         [ 0.06061839],
#         [ 0.0703187 ],
#         [ 0.06924089],
#         [ 0.03582872],
#         [-0.01159501],
#         [-0.046085  ],
#         [ 0.00241654],
#         [-0.04392938],
#         [-0.02560657],
#         [-0.0816528 ],
#         [-0.06979687],
#         [-0.046085  ],
#         [ 0.02720622],
#         [-0.04177375],
#         [ 0.00672779],
#         [ 0.05630715],
#         [ 0.07139652],
#         [ 0.06061839],
#         [-0.01806189],
#         [ 0.05954058],
#         [ 0.11127556],
#         [-0.02452876],
#         [ 0.04552903],
#         [ 0.05954058],
#         [-0.07087468],
#         [-0.02345095],
# ...

# %%
y_pred = regressor.predict(X_train)

# %%
print("coeficients: \n", regressor.coef_)
print("indepentent term: \n", regressor.intercept_)
print("mean square error: %.2f "% mean_squared_error(Y_train,y_pred))
# Out:
# coeficients:
#  [[915.06639233]]
# indepentent term:
#  [152.07011462]
# mean square error: 4126.68

# %%
print(regressor.score(X_test, Y_test))
print("variante score %.2f" % r2_score(Y_train, y_pred))
# Out:
# 0.4011977587831831
# variante score 0.32

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].scatter(X_train, Y_train)
ax[0].plot(X_train, regressor.predict(X_train), c="g")
ax[0].set_title("linear regresion")
ax[0].set_ylabel("target")
ax[1].scatter(X_test, Y_test)
ax[1].plot(X_train, regressor.predict(X_train),c="g")
ax[1].set_title("linear regretion")
ax[1].set_xlabel("train nset")
ax[1].set_ylabel("target")
plt.suptitle("linner regresion model")
# Out:
# Text(0.5, 0.98, 'linner regresion model')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df_diabetes = datasets.load_diabetes()

x = df_diabetes.data[:, 2].reshape(-1, 1)
y = df_diabetes.target

X_train = x[:-20]
X_test  = x[-20:]

Y_train = y[:-20]
Y_test  = y[-20:]

regressor = LinearRegression()
regressor.fit(X_train, Y_train)

y_pred = regressor.predict(X_test)

print("coeficients:\n", regressor.coef_)
print("indepentent term:\n", regressor.intercept_)
print("mean square error: %.2f" % mean_squared_error(Y_test, y_pred))
print("r2 score: %.2f" % r2_score(Y_test, y_pred))

fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].scatter(X_train, Y_train)
ax[0].plot(X_train, regressor.predict(X_train), c="g")
ax[0].set_title("linear regression (train)")
ax[0].set_ylabel("target")

ax[1].scatter(X_test, Y_test)
ax[1].plot(X_test, y_pred, c="g")
ax[1].set_title("linear regression (test)")
ax[1].set_xlabel("BMI")
ax[1].set_ylabel("target")

plt.suptitle("linear regression model")
plt.show()
# Out:
# coeficients:
#  [938.23786125]
# indepentent term:
#  152.91886182616113
# mean square error: 2548.07
# r2 score: 0.47

# %% [markdown]
# El modelo de regresión lineal muestra que existe una relación entre el índice de masa corporal y la progresión de la diabetes. Al separar los datos de forma determinista, se pudo evaluar mejor el desempeño del modelo. Aunque el error indica que las predicciones no son totalmente precisas, el valor de R^2 confirma que el BMI es un predictor relevante, aunque por sí solo no explica todo el comportamiento del modelo.
